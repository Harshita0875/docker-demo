# %%
from kafka import KafkaProducer
import json
import time
import random

# %%
producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0, 15000.0), # >10000 triggers fraud
        "timestamp": time.time()
    }
    producer.send('fraud-detection1', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 105, 'amount': 2480.4005777988045, 'timestamp': 1781850050.7374253}
# Sent: {'tx_id': 1, 'userId': 104, 'amount': 5401.842259871081, 'timestamp': 1781850052.8385618}
# Sent: {'tx_id': 2, 'userId': 101, 'amount': 9710.580660227934, 'timestamp': 1781850054.83906}
# Sent: {'tx_id': 3, 'userId': 101, 'amount': 3159.755961537231, 'timestamp': 1781850056.8395379}
# Sent: {'tx_id': 4, 'userId': 105, 'amount': 13046.28068226416, 'timestamp': 1781850058.8400126}
# Sent: {'tx_id': 5, 'userId': 105, 'amount': 7889.272702506865, 'timestamp': 1781850060.8405113}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 6379.237898946916, 'timestamp': 1781850062.8409395}
# Sent: {'tx_id': 7, 'userId': 105, 'amount': 2611.130885131442, 'timestamp': 1781850064.8414085}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 4791.958434275494, 'timestamp': 1781850066.8418493}
# Sent: {'tx_id': 9, 'userId': 105, 'amount': 7181.325975274228, 'timestamp': 1781850068.8423188}
# Sent: {'tx_id': 10, 'userId': 104, 'amount': 5518.03975197297, 'timestamp': 1781850070.8427362}
# Sent: {'tx_id': 11, 'userId': 103, 'amount': 9127.372952071437, 'timestamp': 1781850072.8431869}
# Sent: {'tx_id': 12, 'userId': 103, 'amount': 138.38112431984322, 'timestamp': 1781850074.8436553}
# Sent: {'tx_id': 13, 'userId': 105, 'amount': 12940.356891990237, 'timestamp': 1781850076.8440893}
# Sent: {'tx_id': 14, 'userId': 102, 'amount': 308.5968340093904, 'timestamp': 1781850078.8456652}
# Sent: {'tx_id': 15, 'userId': 105, 'amount': 12576.06777942588, 'timestamp': 1781850080.846105}
# Sent: {'tx_id': 16, 'userId': 104, 'amount': 2969.9383534871727, 'timestamp': 1781850082.8465803}
# Sent: {'tx_id': 17, 'userId': 102, 'amount': 7650.462200646079, 'timestamp': 1781850084.8480153}
# Sent: {'tx_id': 18, 'userId': 105, 'amount': 363.3908515402502, 'timestamp': 1781850086.8484912}
# Sent: {'tx_id': 19, 'userId': 104, 'amount': 3903.3473762631006, 'timestamp': 1781850088.8489437}
# Sent: {'tx_id': 20, 'userId': 105, 'amount': 1649.9936966937, 'timestamp': 1781850090.8494182}
# Sent: {'tx_id': 21, 'userId': 101, 'amount': 9460.442004623046, 'timestamp': 1781850092.8508518}
# Sent: {'tx_id': 22, 'userId': 101, 'amount': 1506.3217873868145, 'timestamp': 1781850094.85457}
# Sent: {'tx_id': 23, 'userId': 105, 'amount': 11614.613638603892, 'timestamp': 1781850096.8550432}
# Sent: {'tx_id': 24, 'userId': 103, 'amount': 3674.620427539437, 'timestamp': 1781850098.8555446}
# Sent: {'tx_id': 25, 'userId': 103, 'amount': 8784.882084637347, 'timestamp': 1781850100.8561807}
